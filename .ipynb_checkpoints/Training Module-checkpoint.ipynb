# %%
import pandas as pd

# Read in track metadata with genre labels
# tracks = pd.read_csv('https://github.com/Oysiyl/DataCamp_Solutions_Python/blob/master/Classify%20Song%20Genres%20from%20Audio%20Data/datasets/fma-rock-vs-hiphop.csv')
# tracks = pd.read_csv('Documents/VandyHacks/fma-rock-vs-hiphop.csv')

tracks = pd.read_csv('songDb.tsv', sep = '\t', encoding = "ISO-8859-1")

# Read in track metrics with the features

# echonest_metrics = pd.read_json('Documents/VandyHacks/echonest-metrics.json',precise_float=True)

# Merge the relevant columns of tracks and echonest_metrics
# echo_tracks = echonest_metrics.merge(tracks[['track_id','genre_top']],on='track_id')

# Inspect the resultant dataframe
echo_tracks = tracks
# echo_tracks["Tempo"] = echo_tracks.Tempo.astype(float)
print(tracks.info())
print(tracks.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131580 entries, 0 to 131579
# Data columns (total 20 columns):
# Name                131578 non-null object
# Danceability        131580 non-null float64
# Energy              131580 non-null float64
# Key                 131580 non-null float64
# Loudness            131580 non-null float64
# Mode                131580 non-null float64
# Speechness          131580 non-null float64
# Acousticness        131580 non-null float64
# Instrumentalness    131580 non-null float64
# Liveness            131580 non-null float64
# Valence             131580 non-null float64
# Tempo               131580 non-null object
# Type                131580 non-null object
# ID                  131580 non-null object
# Uri                 131580 non-null object
# Ref_Track           131580 non-null object
# URL_features        131580 non-null object
# Duration_ms         131580 non-null float64
# time_signature      131580 non-null object
# Genre               131554 non-null object
# dtypes: float64(11), object(9)
# memory usage: 20.1+ MB
# None
#            Name  Danceability  Energy   Key  Loudness  Mode  Speechness  \
# 0    YuveYuveYu         0.624   0.857  10.0    -6.250   0.0      0.0542
# 1   Gloryhammer         0.517   0.916   0.0    -4.933   1.0      0.0559
# 2        Nostos         0.251   0.894   8.0    -4.103   0.0      0.0570
# 3     Yggdrasil         0.469   0.743   1.0    -5.570   0.0      0.0272
# 4  Incense&Iron         0.487   0.952   1.0    -4.429   0.0      0.0613
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo            Type  \
# 0      0.020800          0.206000     0.110    0.324  131.926  audio_features
# 1      0.000182          0.001910     0.306    0.444  135.996  audio_features
# 2      0.014400          0.000000     0.123    0.297  114.223  audio_features
# 3      0.002220          0.000111     0.276    0.481   86.953  audio_features
# 4      0.000228          0.000000     0.161    0.329  125.993  audio_features
#
#                        ID                                   Uri  \
# 0  6J2VvzKwWc2f0JP5RQVZjq  spotify:track:6J2VvzKwWc2f0JP5RQVZjq
# 1  4HA34COgxgVJ6zK88UN4Ik  spotify:track:4HA34COgxgVJ6zK88UN4Ik
# 2  3W6Xik6Xxf06JuUoZSATlD  spotify:track:3W6Xik6Xxf06JuUoZSATlD
# 3  2gGveBaLJQMtJ43X4UL5kH  spotify:track:2gGveBaLJQMtJ43X4UL5kH
# 4  1lRF81A1C9QoCgBcEop2zg  spotify:track:1lRF81A1C9QoCgBcEop2zg
#
#                                            Ref_Track  \
# 0  https://api.spotify.com/v1/tracks/6J2VvzKwWc2f...
# 1  https://api.spotify.com/v1/tracks/4HA34COgxgVJ...
# 2  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
# 3  https://api.spotify.com/v1/tracks/2gGveBaLJQMt...
# 4  https://api.spotify.com/v1/tracks/1lRF81A1C9Qo...
#
#                                         URL_features  Duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6J2V...     282920.0
# 1  https://api.spotify.com/v1/audio-analysis/4HA3...     300320.0
# 2  https://api.spotify.com/v1/audio-analysis/3W6X...     175353.0
# 3  https://api.spotify.com/v1/audio-analysis/2gGv...     272292.0
# 4  https://api.spotify.com/v1/audio-analysis/1lRF...     237933.0
#
#   time_signature        Genre
# 0            4.0  celticmetal
# 1            4.0  celticmetal
# 2            4.0  celticmetal
# 3            4.0  celticmetal
# 4            4.0  celticmetal
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col5 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col6 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col7 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col9 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row0_col10 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col4 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col5 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col7 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col8 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col9 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row1_col10 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col1 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col3 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col5 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col6 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col7 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col8 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col9 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row2_col10 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col1 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col4 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col5 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col9 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col1 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col3 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col5 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col6 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col7 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col8 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col9 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row4_col10 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row5_col0 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row5_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row5_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row5_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_2fe47ff2_fdb8_11e9_8acc_9a0010e7bf60row5_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000

# %%
# Import numpy
import numpy as np
labels = echo_tracks['Genre']
labels = labels.to_numpy()
#print(labels[5000:5100])
unique_list = np.unique(labels.astype(str))
print(unique_list)
#print(len(labels))
#Define our Tempos
tempos = echo_tracks['Tempo']
# print(tempos[1:10])
# print(len(tempos))
# tempos = tempos.astype(float)
# print(type(tempos))

# Define our features 
features = echo_tracks.drop(['Name', 'Tempo', 'Type', 'ID', 'Uri', 'Ref_Track', 'URL_features', 'Duration_ms','time_signature', 'Genre'], axis=1)

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# print(features.info())
# print(tempos.head())

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
# Out:
# ['abstractidm' 'acappella' 'acousticpunk' 'africangospel' 'afropsych'
#  'alaskaindie' 'albanianhiphop' 'albertacountry' 'albuquerqueindie'
#  'alternativeamericana' 'alternativeemo' 'alternativer&b'
#  'alternativerootsrock' 'ambeat' 'ambientworship' 'americanchoir'
#  'americanfolkrevival' 'animescore' 'anthemworship' 'arabalternative'
#  'arabichiphop' 'argentineindie' 'arpaparaguaya' 'atmosphere'
#  'atmosphericpost-metal' 'atmosphericpost-rock' 'aucklandindie'
#  'aussieemo' 'australianindiefolk' 'australianpop' 'australianrock'
#  'australianundergroundhiphop' 'austrianhiphop' 'austrianmetal' 'azeripop'
#  'bahai' 'balkantrap' 'balletclass' 'balticfolk' 'basquerock' 'bboy'
#  'beats' 'bedroompop' 'belfastindie' 'belgianexperimental'
#  'belgianindierock' 'belgianmetal' 'belgianpop' 'birminghamindie'
#  'blues-rock' 'bluesband' 'bmore' 'bossanova' 'bossanovajazz'
#  'bostonmetal' 'bouncyhouse' 'brazilianelectronica' 'brazilianindierock'
#  'brazilianreggae' 'brazilianska' 'breakcore' 'bretonfolk' 'brightonindie'
#  'britishbrassband' 'britishchoir' 'britishcomedy' 'britishindierock'
#  'britishjazz' 'bubbletrance' 'buffalonyindie' 'canadianclassical'
#  'canadianelectropop' 'canadianpop' 'canadianrock' 'canadiansoundtrack'
#  'cancoesinfantis' 'cantautor' 'canteflamenco' 'canterburyscene'
#  'catalanfolk' 'celtic' 'celticmetal' 'chamame' 'chamberchoir'
#  'chamberensemble' 'channelpop' 'chanson' 'chansonpaillarde'
#  'chaoticblackmetal' 'chicagohouse' 'chicagoindie' 'chicagopunk'
#  'chillstep' 'chineseexperimental' 'chineseguzheng' 'chineseopera'
#  'chiphop' 'chiptune' 'choro' 'christianacappella' 'christianafrobeat'
#  'christianpop' 'christianpunk' 'christianrelaxative' 'christmas'
#  'classicalbaritone' 'classicalguitarquartet' 'classicalpercussion'
#  'classicalsaxophone' 'classicalsaxophonequartet' 'classicaltrumpet'
#  'classicdanishpop' 'classicgaragerock' 'classicopm' 'classicsoul'
#  'classicsoundtrack' 'classicswedishpop' 'classify' 'collegemarchingband'
#  'colombianindie' 'colombianrock' 'columbusohioindie' 'contemporaryjazz'
#  'cornetasytambores' 'cornwallindie' 'corsicanfolk' 'country'
#  'countrydawn' 'countryrap' 'coventryindie' 'crossoverthrash' 'crustpunk'
#  'cubaton' 'cumbiaperuana' 'cumbiapop' 'cyberpunk' 'czechelectronic'
#  'czechfolk' 'czechhiphop' 'czechindie' 'czechpop' 'czechrock'
#  'dallasindie' 'dancepop' 'dancerock' 'danishclassical' 'danishindiepop'
#  'danishpop' 'danishpoprock' 'dansktop' 'darkambient' 'darkblackmetal'
#  'darkcabaret' 'darkpost-punk' 'darkprogressivehouse' 'darktechno'
#  'darktrap' 'darkwave' 'deathgrind' 'deepbrazilianpop' 'deepccm'
#  'deepchill-out' 'deepchristianrock' 'deepcomedy' 'deepdancepop'
#  'deepdeephouse' 'deepdisco' 'deepdubtechno' 'deepeurodance'
#  'deepfilthstep' 'deepfunk' 'deepgroovehouse' 'deepidm' 'deepindierock'
#  'deeplatinjazz' 'deepnorteno' 'deeppoppunk' 'deeppower-poppunk'
#  'deeppsychobilly' 'deepragga' 'deeprai' 'deepsmoothjazz' 'deepsoftrock'
#  'deepsoundtrack' 'deepsouthernsoul' 'demoscene' 'depressiveblackmetal'
#  'detroitindie' 'dmvrap' 'dominicanindie' 'doo-wop' 'doujin' 'downtempo'
#  'dreampop' 'drillandbass' 'dronefolk' 'dronemetal' 'dronescape'
#  'drumandbass' 'drumfunk' 'dublinindie' 'dubstep' 'dubsteppe'
#  'dunedinindie' 'e6fi' 'earlyavantgarde' 'earlymusic' 'earlyromanticera'
#  'ecuadoria' 'ecuadorianalternativerock' 'ecuadorianindie' 'edm'
#  'electrolatino' 'electronic' 'electronica' 'electronicore' 'elpasoindie'
#  'emorap' 'epicore' 'esperanto' 'essexindie' 'estonianhiphop'
#  'estonianjazz' 'etherealwave' 'etherpop' 'europop' 'euroska' 'eurovision'
#  'experimentalhiphop' 'experimentalhouse' 'experimentalpsych'
#  'fingerstyle' 'finnishblackmetal' 'finnishedm' 'finnishfolk'
#  'finnishhiphop' 'finnishjazz' 'finnishworship' 'flemishfolk' 'fluxwork'
#  'focus' 'folclorcolombiano' 'freakbeat' 'freestyle' 'frenchfolk'
#  'frenchfolkpop' 'frenchhiphop' 'frenchopera' 'frenchpunk' 'funeraldoom'
#  'funkrock' 'funkybreaks' 'futureambient' 'futurefunk' 'gabba'
#  'galicianfolk' 'garagerock' 'gauzepop' 'gbvfi' 'geekrock'
#  'germanhardcore' 'germanhardrock' 'germanjazz' 'germanoi' 'germanpop'
#  'germanpost-rock' 'germanpunk' 'germanrenaissance' 'germantechno'
#  'germanworship' 'ghanaianhiphop' 'ghettotech' 'girlgroup' 'glitchbeats'
#  'glittertrance' 'go-go' 'goatrance' 'gospelblues' 'gospelr&b'
#  'gothicmetal' 'gothicrock' 'gothicsymphonicmetal' 'greekblackmetal'
#  'greekhouse' 'greenlandicpop' 'groovemetal' 'grungepop' 'guatemalanindie'
#  'guitarcase' 'halifaxindie' 'handsup' 'hardcorepunk' 'hardglam'
#  'hardminimaltechno' 'hardstyle' 'hardvapour' 'hi-nrg' 'hiphop' 'hiphouse'
#  'hippop' 'historicallyinformedperformance' 'historicclassicalperformance'
#  'hollywood' 'hongkongindie' 'hungarianhiphop' 'hungarianpunk'
#  'icelandicindie' 'icelandicpop' 'icelandicrock' 'idahoindie'
#  'indianindie' 'indieemorock' 'indiegaragerock' 'indienapoletano'
#  'indiepoptimism' 'indietico' 'indonesianhiphop' 'indonesianpop'
#  'indonesianpoppunk' 'indonesianworship' 'instrumentalprogressivemetal'
#  'intelligentdancemusic' 'irishclassical' 'irishfolk' 'israeliindie'
#  'italianbaroque' 'italianhiphop' 'italianindiepop'
#  'italianoccultpsychedelia' 'italianpost-rock' 'italianrenaissance'
#  'italianska' 'italianundergroundhiphop' 'j-core' 'j-dance' 'j-rap'
#  'japanesedeathmetal' 'japaneser&b' 'jazzelectricbass' 'jazzfusion'
#  'jerseyclub' 'keroncong' 'khmer' 'kindierock' 'koreanmetal' 'koreanpop'
#  'kwaito' 'lapop' 'lateromanticera' 'latinafrobeat' 'latinchristian'
#  'latinfunk' 'latinmetal' 'leedsindie' 'lgbtq+hiphop' 'liverpoolindie'
#  'lowercase' 'madchester' 'mallet' 'malmoindie' 'mandepop'
#  'manitobacountry' 'marchafunebre' 'martialindustrial' 'mathcore'
#  'mathpop' 'medieval' 'medievalrock' 'meditation' 'melbourneindie'
#  'mellowgold' 'melodicdeathmetal' 'melodicmetalcore' 'messianicpraise'
#  'metalguitar' 'metallichardcore' 'mexicanedm' 'mexicanpoppunk'
#  'mexicanrock-and-roll' 'michiganindie' 'microhouse' 'microtonal'
#  'midwestemo' 'milanindie' 'minimaldub' 'minimaldubstep' 'minimaltechno'
#  'minneapolisindie' 'minneapolispunk' 'modernblues' 'moderncountryrock'
#  'modernperformance' 'monterreyindie' 'moog' 'mpb' 'musicadepernambuco'
#  'musicaperbambini' 'musicbox' 'musiikkialapsille' 'musikanak-anak'
#  'musiqueacadienne' 'muzicacrestina' 'nan' 'nativeamericanhiphop'
#  'necrogrind' 'neo-tradmetal' 'neoclassical' 'neosoul-jazz'
#  'neuedeutschewelle' 'neurostep' 'newjackswing' 'newrave' 'newromantic'
#  'newwavepop' 'nlfolk' 'noisepop' 'noisepunk'
#  'nordiccontemporaryclassical' 'nordichouse' 'northeastenglandindie'
#  'norwegianchoir' 'norwegianclassical' 'norwegiandeathmetal'
#  'norwegianfolk' 'norwegianhiphop' 'norwegianindie' 'norwegianmetal'
#  'norwegianpunk' 'novampb' 'nuelectro' 'nuevacancion' 'oberkrainer'
#  'okinawanfolk' 'okindie' 'oratory' 'orchestralperformance'
#  'organicambient' 'ostrock' 'otacore' 'outerhiphop' 'panamanianrock'
#  'panpipe' 'pasodobles' 'persianneo-traditional' 'persiantraditional'
#  'peruvianhiphop' 'peruvianindie' 'peruvianmetal' 'petcalming'
#  'phoenixindie' 'pianoblues' 'pixie' 'polishblackmetal' 'polishclassical'
#  'polishfolk' 'polishpop' 'polishpunk' 'polynesianpop' 'polyphony'
#  'popedm' 'popemo' 'popping' 'poprap' 'porro' 'portlandhiphop'
#  'portugueseearlymusic' 'portuguesefolk' 'portugueseindie' 'portuguesepop'
#  'portugueserock' 'post-blackmetal' 'post-disco' 'post-metal'
#  'post-rocklatinoamericano' 'post-romanticera' 'progressivebluegrass'
#  'progressivebreaks' 'progressivedeathcore' 'progressivetrance'
#  'progressiveupliftingtrance' 'protopunk' 'psalmen'
#  'psychedelicblues-rock' 'psychedelicfolk' 'psychedelicrock'
#  'psychedelictrance' 'psychill' 'punta' 'quietstorm' 'r&b' 'r&bbrasileiro'
#  'ranchera' 'rapdominicano' 'rapmetal' 'rapmetalcore' 'raregroove'
#  'reading' 'rebetiko' 'reggae' 'reggaerock' 'reggaeton'
#  'regionalmexicanpop' 'renaissance' 'rhythmandblues' 'riddim' 'rock'
#  'rockcatala' 'rockkapak' 'rocknacional' 'rocktico' 'romanianfolk'
#  'romanianindie' 'romaniantrap' 'rootsreggae' 'rosary' 'rumbacatalana'
#  'runefolk' 'russianelectronic' 'russianjazz' 'russianpunk'
#  'russianreggae' 'rvaindie' 'salsa' 'salsainternational' 'sanantonioindie'
#  'scandinavianr&b' 'schoolensemble' 'scorecore' 'scottishhiphop' 'scratch'
#  'seattleindie' 'shanty' 'showtunes' 'sinhala' 'skweee' 'skyroom'
#  'slavicmetal' 'slovakindie' 'slovakrock' 'sludgemetal' 'smoothjazz'
#  'soul' 'southafricanjazz' 'southernamericana' 'southernrock'
#  'spaceambient' 'spanishfolk' 'spiritualjazz' 'steampunk' 'steelguitar'
#  'stlindie' 'substep' 'sungpoetry' 'sunsetlounge' 'swedishdeathmetal'
#  'swedishhardrock' 'swedishindiepop' 'swedishpoppunk' 'swedishprog'
#  'swedishrockabilly' 'swedishsoul' 'swedishsynthpop' 'swing'
#  'swisscountry' 'swissindie' 'sydneyindie' 'symphonicpowermetal'
#  'tahitian' 'tango' 'tassieindie' 'technicalblackmetal' 'thaipop'
#  'thrashcore' 'thrashmetal' 'tijuanaelectronic' 'torontoindie'
#  'traditionalbritishfolk' 'traditionalenglishfolk' 'traditionalfolk'
#  'trance' 'trapfrancais' 'trikiti' 'tropicalhouse' 'turkishelectronic'
#  'turkishexperimental' 'turkishfolk' 'turkishhiphop' 'turkishmetal'
#  'ukalternativepop' 'ukamericana' 'ukdiypunk' 'uknoiserock' 'ukpop'
#  'ukpost-punk' 'undergroundlatinhiphop' 'undergroundpowerpop'
#  'undergroundrap' 'urbancontemporary' 'v-pop' 'vallenato' 'vaporpop'
#  'vaporsoul' 'vegasindie' 'venezuelanhiphop' 'victoriabcindie'
#  'videogamemusic' 'vietnamesebolero' 'vikingmetal' 'vintagechanson'
#  'vintagegospel' 'vintagehawaiian' 'vintageradioshow' 'visualkei'
#  'vocaljazz' 'vocaltrance' 'volksmusik' 'welshchoir' 'welshindie'
#  'welshmetal' 'westernmassindie' 'witchhouse' 'worship' 'wrock'
#  'yugoslavrock' 'zapstep' 'zeuhl']
# 131580

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')

# %%
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, 
                                                                            labels,
                                                                            random_state=10)


train_labels = train_labels.astype(str)
test_labels = test_labels.astype(str)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)



# # Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
tree.score(test_features, test_labels)

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=3)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks[echo_tracks['Genre']=='Hip-Hop']
rock_only = echo_tracks[echo_tracks['Genre']=='Rock']
electronic_only = echo_tracks[echo_tracks['Genre']=='Electronic']
experimental_only = echo_tracks[echo_tracks['Genre']=='Experimental']
instrumental_only = echo_tracks[echo_tracks['Genre']=='Instrumental']
folk_only = echo_tracks[echo_tracks['Genre']=='Folk']
pop_only = echo_tracks[echo_tracks['Genre']=='Pop']
international_only = echo_tracks[echo_tracks['Genre']=='International']

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = rock_only.sample(len(hop_only), random_state=10)
electronic_only = electronic_only.sample(len(hop_only), random_state=10)
experimental_only = experimental_only.sample(len(hop_only), random_state=10)
instrumental_only = instrumental_only.sample(len(hop_only), random_state=10)
folk_only = folk_only.sample(len(hop_only), random_state=10)
pop_only = pop_only.sample(len(hop_only), random_state=10)
international_only = international_only.sample(len(hop_only), random_state=10)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only, electronic_only, experimental_only, instrumental_only, folk_only, pop_only, international_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['Genre', 'track_id'], axis=1) 
labels = rock_hop_bal['Genre']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(10, random_state=10)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", tree_score, "Logistic Regression:", logit_score)
