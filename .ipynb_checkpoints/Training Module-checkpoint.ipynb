# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv('mod_spotify.csv')

# Inspect the resultant dataframe
echo_tracks = tracks

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col3 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e15617ce_fe48_11e9_b598_9a0010e7bf60row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
# ...

# %%
# Import numpy
import numpy as np
labels = echo_tracks['Genre']
labels = labels.to_numpy()
unique_list = np.unique(labels.astype(str))

# Define our features 
features = echo_tracks.drop(['Genre'], axis = 1)

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
print(scaled_train_features.shape)
# Out:
# (3152, 10)

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, 
                                                                            labels,
                                                                            random_state=10)


train_labels = train_labels.astype(str)
test_labels = test_labels.astype(str)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=20)
tree.fit(train_features, train_labels)



# # Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
tree.score(test_features, test_labels)
# Out:
# 0.5253807106598984

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      country       0.53      0.54      0.53       175
#       hiphop       0.72      0.69      0.70       174
#         jazz       0.34      0.41      0.37        75
#          r&b       0.46      0.40      0.42       184
#         rock       0.50      0.53      0.51       180
#
#     accuracy                           0.53       788
#    macro avg       0.51      0.51      0.51       788
# weighted avg       0.53      0.53      0.53       788
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      country       0.47      0.67      0.55       175
#       hiphop       0.68      0.79      0.73       174
#         jazz       0.46      0.32      0.38        75
#          r&b       0.48      0.42      0.45       184
#         rock       0.48      0.32      0.38       180
#
#     accuracy                           0.53       788
# ...

# %%
# Subset only the hip-hop tracks, and then only the rock tracks

seperatedTracks = []
for i in unique_list:
    seperatedTracks.append(echo_tracks[echo_tracks['Genre']==i])


minSize = -1
for i in seperatedTracks:
    if len(i) < minSize or minSize == -1:
        minSize = len(i)
# sample the rocks songs to be the same number as there are hip-hop songs
for i,x in enumerate(seperatedTracks):
    seperatedTracks[i] = x.sample(minSize, random_state=10)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat(seperatedTracks)

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['Genre'], axis=1) 
labels = rock_hop_bal['Genre']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)



# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      country       0.58      0.60      0.59        83
#       hiphop       0.64      0.66      0.65        82
#         jazz       0.54      0.48      0.51        93
#          r&b       0.41      0.52      0.46        81
#         rock       0.52      0.44      0.48       101
#
#     accuracy                           0.53       440
#    macro avg       0.54      0.54      0.54       440
# weighted avg       0.54      0.53      0.53       440
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      country       0.44      0.64      0.52        83
#       hiphop       0.59      0.74      0.66        82
#         jazz       0.57      0.63      0.60        93
#          r&b       0.42      0.44      0.43        81
#         rock       0.52      0.14      0.22       101
#
#     accuracy                           0.51       440
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(10, random_state=10)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", tree_score, "Logistic Regression:", logit_score)
# Out:
# Decision Tree: [0.36931818 0.38636364 0.4375     0.53977273 0.44318182 0.42045455
#  0.30681818 0.4375     0.32386364 0.30681818] Logistic Regression: [0.26136364 0.36931818 0.64772727 0.63068182 0.34659091 0.34090909
#  0.15340909 0.19318182 0.02840909 0.00568182]
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
spotify_data = pd.read_csv('songDb.tsv', sep = '\t', encoding = 'ISO-8859-1')
spotify_data = spotify_data.drop(['Mode', 'Type', 'ID', 'Uri', 'Ref_Track', 'URL_features', 'Duration_ms','time_signature', 'Genre'], axis=1)


def getSongFeatures(song):
    features = spotify_data[spotify_data["Name"] == song][:1]
    return features


def getSongGenre(input_features):
    labels = rock_hop_bal['Genre']
    tree = DecisionTreeClassifier(random_state=10)
    tree.fit(features, labels)
    pred_labels_tree = tree.predict(input_features)
    return pred_labels_tree
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def getSimilarSongs(input_genre):
    spotify_data2 = pd.read_csv('songDb.tsv', sep = '\t', encoding = 'ISO-8859-1')
    genre_name = spotify_data2.drop(['Mode', 'Type', 'ID', 'Uri', 'Ref_Track', 'URL_features', 'Duration_ms','time_signature', "Danceability", "Energy", "Key", "Speechness", "Acousticness", "Instrumentalness", "Liveness", "Valence", "Tempo", "Loudness"], axis=1)
    genre_name = genre_name[genre_name["Genre"] == input_genre]
    #print(np.unique(genre_name["Genre"].to_string()))
#     for i in genre_name:
#         print(i)
    genre_name = genre_name.drop(['Genre'], axis=1)
    np.random.shuffle(genre_name.to_numpy())
    return genre_name[0:3]
    
print(getSimilarSongs("rock"))
# Out:
#                                         Name
# 112123                  SmellsLikeTeenSpirit
# 112124                     BlackDog-Remaster
# 112125  HereIGoAgain87-2017RemasteredVersion
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (11,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
